-- %% [markdown]
-- ### Lets see initial status of all tables before creating Pipeline
-- ### and before Creating Jobs and executing end to end flow

-- %%
-- Count of Bronze Traffic Rows

SELECT COUNT(*) FROM `dev-catalog`.`bronze`.raw_traffic
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>55638</td></tr></tbody></table></div>

-- %%
-- Count of Bronze Roads Rows

SELECT COUNT(*) FROM `dev-catalog`.`bronze`.raw_roads
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>228</td></tr></tbody></table></div>

-- %%
-- Count of Silver Traffic Rows

SELECT COUNT(*) FROM `dev-catalog`.`silver`.silver_traffic
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>55638</td></tr></tbody></table></div>

-- %%
-- Count of Silver Roads Rows

SELECT COUNT(*) FROM `dev-catalog`.`silver`.silver_roads
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>228</td></tr></tbody></table></div>

-- %%
-- Count of Gold Traffic Rows

SELECT COUNT(*) FROM `dev-catalog`.`gold`.gold_traffic
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>55638</td></tr></tbody></table></div>

-- %%
-- Count of Gold Road Rows

SELECT COUNT(*) FROM `dev-catalog`.`gold`.gold_roads
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>228</td></tr></tbody></table></div>

-- %% [markdown]
-- ##### upload raw_traffic4.csv file into raw_traffic directory in landing directory
-- ##### and upload raw_roads4.csv file into raw_roads directory in landing directory

-- %% [markdown]
-- #### now create Workflow in "Workflow" section
